# %% [markdown]
# # InsightIQ - Exploratory Data Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Load Data
df = pd.read_csv('../data/raw/student_performance_raw.csv')
df.head()

# %%
df.info()

# %%
df.describe()

# %%
# Distribution of Final Grades
sns.countplot(x='final_grade', data=df, order=['A', 'B', 'C', 'D'])
plt.title('Distribution of Final Grades')
plt.show()

# %%
# Correlation Heatmap
# Convert categorical to numeric for correlation
df_numeric = df.copy()
grade_map = {'A': 4, 'B': 3, 'C': 2, 'D': 1}
df_numeric['final_grade_num'] = df_numeric['final_grade'].map(grade_map)

plt.figure(figsize=(10, 8))
sns.heatmap(df_numeric.corr(), annot=True, cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
# Pairplot
sns.pairplot(df, hue='final_grade')
plt.show()
